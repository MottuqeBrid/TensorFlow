# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
def sigmoid(x):
    return 1 / (1 + math.exp(-x))

# %%
sig = sigmoid(100)
sig
# Out:
# 1.0

# %%
sigmoid(-100)
# Out:
# 3.7200759760208356e-44

# %%
sigmoid(1)
# Out:
# 0.7310585786300049

# %%
sigmoid(0)
# Out:
# 0.5
